# %%
from statsbombpy import sb
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.colors import to_rgba

# %%
sb.competitions()
# Out:
# c:\Users\aakas\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         90                   England
# 16              37         42                   England
# 17              37          4                   England
# 18              43          3             International
# 19              11         90                     Spain
# 20              11         42                     Spain
# 21              11          4                     Spain
# 22              11          1                     Spain
# 23              11          2                     Spain
# 24              11         27                     Spain
# 25              11         26                     Spain
# 26              11         25                     Spain
# 27              11         24                     Spain
# 28              11         23                     Spain
# 29              11         22                     Spain
# 30              11         21                     Spain
# 31              11         41                     Spain
# 32              11         40                     Spain
# 33              11         39                     Spain
# 34              11         38                     Spain
# 35              11         37                     Spain
# 36              49          3  United States of America
# 37               2         44                   England
# 38              55         43                    Europe
# 39              53        106                    Europe
# 40              72         30             International
#
#            competition_name competition_gender  competition_youth  \
# 0          Champions League               male              False
# 1          Champions League               male              False
# 2          Champions League               male              False
# 3          Champions League               male              False
# 4          Champions League               male              False
# 5          Champions League               male              False
# 6          Champions League               male              False
# 7          Champions League               male              False
# 8          Champions League               male              False
# 9          Champions League               male              False
# 10         Champions League               male              False
# 11         Champions League               male              False
# 12         Champions League               male              False
# 13         Champions League               male              False
# 14         Champions League               male              False
# 15  FA Women's Super League             female              False
# 16  FA Women's Super League             female              False
# 17  FA Women's Super League             female              False
# 18           FIFA World Cup               male              False
# 19                  La Liga               male              False
# 20                  La Liga               male              False
# 21                  La Liga               male              False
# 22                  La Liga               male              False
# 23                  La Liga               male              False
# 24                  La Liga               male              False
# 25                  La Liga               male              False
# 26                  La Liga               male              False
# 27                  La Liga               male              False
# 28                  La Liga               male              False
# 29                  La Liga               male              False
# 30                  La Liga               male              False
# 31                  La Liga               male              False
# 32                  La Liga               male              False
# 33                  La Liga               male              False
# 34                  La Liga               male              False
# 35                  La Liga               male              False
# 36                     NWSL             female              False
# 37           Premier League               male              False
# 38                UEFA Euro               male              False
# 39        UEFA Women's Euro             female              False
# 40        Women's World Cup             female              False
#
#     competition_international season_name               match_updated  \
# 0                       False   2018/2019  2022-08-14T16:57:15.866765
# 1                       False   2017/2018  2021-08-27T11:26:39.802832
# 2                       False   2016/2017  2021-08-27T11:26:39.802832
# 3                       False   2015/2016  2021-08-27T11:26:39.802832
# 4                       False   2014/2015  2021-08-27T11:26:39.802832
# 5                       False   2013/2014  2021-08-27T11:26:39.802832
# 6                       False   2012/2013  2021-08-27T11:26:39.802832
# 7                       False   2011/2012  2021-08-27T11:26:39.802832
# 8                       False   2010/2011  2022-01-26T21:07:11.033473
# 9                       False   2009/2010  2022-02-12T16:13:49.294747
# 10                      False   2008/2009  2021-11-07T14:20:01.699993
# 11                      False   2006/2007  2021-03-31T04:18:30.437060
# 12                      False   2004/2005  2021-04-01T06:18:57.459032
# 13                      False   2003/2004  2021-04-01T00:34:59.472485
# 14                      False   1999/2000            2020-07-29T05:00
# 15                      False   2020/2021  2022-08-16T02:10:37.220648
# 16                      False   2019/2020     2021-06-01T13:01:18.188
# 17                      False   2018/2019  2022-05-27T12:02:24.272045
# 18                       True        2018  2022-08-04T21:58:22.163987
# 19                      False   2020/2021     2022-02-11T14:56:09.076
# 20                      False   2019/2020  2022-07-15T23:27:24.260122
# 21                      False   2018/2019  2022-08-16T11:40:02.267640
# 22                      False   2017/2018  2022-08-13T23:18:38.928566
# 23                      False   2016/2017  2022-01-25T22:51:59.353598
# 24                      False   2015/2016  2022-05-25T14:00:13.468337
# 25                      False   2014/2015  2022-08-14T18:49:03.341489
# 26                      False   2013/2014  2022-07-23T12:18:49.547396
# 27                      False   2012/2013  2021-10-27T15:44:43.940862
# 28                      False   2011/2012            2020-07-29T05:00
# 29                      False   2010/2011  2021-11-11T22:57:42.361902
# 30                      False   2009/2010  2021-10-26T13:56:40.989214
# 31                      False   2008/2009            2020-07-29T05:00
# 32                      False   2007/2008  2021-10-26T13:13:56.180589
# 33                      False   2006/2007            2020-07-29T05:00
# 34                      False   2005/2006  2022-07-03T12:34:31.749038
# 35                      False   2004/2005            2020-07-29T05:00
# 36                      False        2018  2021-11-06T05:53:29.435016
# 37                      False   2003/2004  2021-11-14T22:29:00.646120
# 38                       True        2020  2022-02-01T17:20:34.319496
# 39                       True        2022  2022-08-01T07:46:11.595364
# 40                       True        2019  2022-07-13T20:21:27.033445
#
#              match_updated_360         match_available_360  \
# 0      2021-06-13T16:17:31.694                        None
# 1      2021-06-13T16:17:31.694                        None
# 2      2021-06-13T16:17:31.694                        None
# 3      2021-06-13T16:17:31.694                        None
# 4      2021-06-13T16:17:31.694                        None
# 5      2021-06-13T16:17:31.694                        None
# 6      2021-06-13T16:17:31.694                        None
# 7      2021-06-13T16:17:31.694                        None
# 8      2021-06-13T16:17:31.694                        None
# 9      2021-06-13T16:17:31.694                        None
# 10     2021-06-13T16:17:31.694                        None
# 11     2021-06-13T16:17:31.694                        None
# 12     2021-06-13T16:17:31.694                        None
# 13     2021-06-13T16:17:31.694                        None
# 14     2021-06-13T16:17:31.694                        None
# 15     2021-06-13T16:17:31.694                        None
# 16     2021-06-13T16:17:31.694                        None
# 17     2021-06-13T16:17:31.694                        None
# 18     2021-06-13T16:17:31.694                        None
# 19  2022-08-16T21:50:36.812060  2022-08-16T21:50:36.812060
# 20     2021-06-13T16:17:31.694                        None
# 21  2021-07-09T14:53:22.103024                        None
# 22     2021-06-13T16:17:31.694                        None
# 23     2021-06-13T16:17:31.694                        None
# 24     2021-06-13T16:17:31.694                        None
# 25     2021-06-13T16:17:31.694                        None
# 26     2021-06-13T16:17:31.694                        None
# 27     2021-06-13T16:17:31.694                        None
# 28     2021-06-13T16:17:31.694                        None
# 29     2021-06-13T16:17:31.694                        None
# 30     2021-06-13T16:17:31.694                        None
# 31     2021-06-13T16:17:31.694                        None
# 32     2021-06-13T16:17:31.694                        None
# 33     2021-06-13T16:17:31.694                        None
# 34     2021-06-13T16:17:31.694                        None
# 35     2021-06-13T16:17:31.694                        None
# 36     2021-06-13T16:17:31.694                        None
# 37     2021-06-13T16:17:31.694                        None
# 38            2022-08-04T12:00            2022-08-04T12:00
# 39  2022-08-27T17:17:09.967851  2022-08-26T00:43:22.824600
# 40     2021-06-13T16:17:31.694                        None
#
#                match_available
# 0   2022-08-14T16:57:15.866765
# 1   2021-01-23T21:55:30.425330
# 2             2020-07-29T05:00
# 3             2020-07-29T05:00
# 4             2020-07-29T05:00
# 5             2020-07-29T05:00
# 6      2021-07-10T13:41:45.751
# 7             2020-07-29T05:00
# 8   2022-01-26T21:07:11.033473
# 9   2022-02-12T16:13:49.294747
# 10  2021-11-07T14:20:01.699993
# 11  2021-03-31T04:18:30.437060
# 12  2021-04-01T06:18:57.459032
# 13  2021-04-01T00:34:59.472485
# 14            2020-07-29T05:00
# 15  2022-08-16T02:10:37.220648
# 16     2021-06-01T13:01:18.188
# 17  2022-05-27T12:02:24.272045
# 18  2022-08-04T21:58:22.163987
# 19     2022-02-11T14:56:09.076
# 20  2022-07-15T23:27:24.260122
# 21  2022-08-16T11:40:02.267640
# 22  2022-08-13T23:18:38.928566
# 23  2022-01-25T22:51:59.353598
# 24  2022-05-25T14:00:13.468337
# 25  2022-08-14T18:49:03.341489
# 26  2022-07-23T12:18:49.547396
# 27  2021-10-27T15:44:43.940862
# 28            2020-07-29T05:00
# 29  2021-11-11T22:57:42.361902
# 30  2021-10-26T13:56:40.989214
# 31            2020-07-29T05:00
# 32  2021-10-26T13:13:56.180589
# 33            2020-07-29T05:00
# 34  2022-07-03T12:34:31.749038
# 35            2020-07-29T05:00
# 36  2021-11-06T05:53:29.435016
# 37  2021-11-14T22:29:00.646120
# 38  2022-02-01T17:20:34.319496
# 39  2022-08-01T07:46:11.595364
# 40  2022-07-13T20:21:27.033445

# %%
t=sb.matches(competition_id=43,season_id=3)
# Out:
# c:\Users\aakas\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)

# %%
t[t['competition_stage']=='Round of 16']
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 13      7580  2018-06-30  16:00:00.000  International - FIFA World Cup   2018
# 15      7581  2018-07-01  20:00:00.000  International - FIFA World Cup   2018
# 26      7583  2018-07-02  16:00:00.000  International - FIFA World Cup   2018
# 29      7584  2018-07-02  20:00:00.000  International - FIFA World Cup   2018
# 35      7582  2018-07-01  16:00:00.000  International - FIFA World Cup   2018
# 41      7579  2018-06-30  20:00:00.000  International - FIFA World Cup   2018
# 51      7585  2018-07-03  20:00:00.000  International - FIFA World Cup   2018
# 52      7586  2018-07-03  16:00:00.000  International - FIFA World Cup   2018
#
#    home_team    away_team  home_score  away_score match_status  ...  \
# 13    France    Argentina           4           3    available  ...
# 15   Croatia      Denmark           1           1    available  ...
# 26    Brazil       Mexico           2           0    available  ...
# 29   Belgium        Japan           3           2    available  ...
# 35     Spain       Russia           1           1    available  ...
# 41   Uruguay     Portugal           2           1    available  ...
# 51  Colombia      England           1           1    available  ...
# 52    Sweden  Switzerland           1           0    available  ...
#
#            last_updated_360 match_week competition_stage  \
# 13  2021-06-13T16:17:31.694          4       Round of 16
# 15  2021-06-13T16:17:31.694          4       Round of 16
# 26  2021-06-13T16:17:31.694          4       Round of 16
# 29  2021-06-13T16:17:31.694          4       Round of 16
# 35  2021-06-13T16:17:31.694          4       Round of 16
# 41  2021-06-13T16:17:31.694          4       Round of 16
# 51  2021-06-13T16:17:31.694          4       Round of 16
# 52  2021-06-13T16:17:31.694          4       Round of 16
#
#                                        stadium                        referee  \
# 13                               Kazan'' Arena                Alireza Faghani
# 15  Stadion Nizhny Novgorod (Nizhniy Novgorod)           Néstor Fabián Pitana
# 26                         \tSolidarnost Arena                Gianluca Rocchi
# 29                              \tRostov Arena                Malang Diedhiou
# 35                            Stadion Luzhniki                  Björn Kuipers
# 41                \tOlimpiyskiy Stadion Fisht   César Arturo Ramos Palazuelos
# 51                    Otkrytiye Arena (Moskva)                    Mark Geiger
# 52                    Saint-Petersburg Stadium                  Damir Skomina
#
#                      home_managers                              away_managers  \
# 13                Didier Deschamps                   Jorge Luis Sampaoli Moya
# 15                    Zlatko Dalić                       Åge Fridtjof Hareide
# 26          Adenor Leonardo Bacchi                Juan Carlos Osorio Arbeláez
# 29       Roberto Martínez Montoliú                              Akira Nishino
# 35            Fernando Ruiz Hierro                       Stanislav Cherchesov
# 41  Óscar Washington Tabárez Silva  Fernando Manuel Fernandes da Costa Santos
# 51            José Néstor Pekerman                           Gareth Southgate
# 52              Jan Olof Andersson                          Vladimir Petković
#
#    data_version shot_fidelity_version xy_fidelity_version
# 13        1.0.2                  None                None
# 15        1.0.2                  None                None
# 26        1.0.2                  None                None
# 29        1.0.2                  None                None
# 35        1.0.2                  None                None
# 41        1.0.2                  None                None
# 51        1.0.2                  None                None
# 52        1.0.2                  None                None
#
# [8 rows x 22 columns]

# %%
df=sb.events(match_id=7580)
# Out:
# c:\Users\aakas\AppData\Local\Programs\Python\Python310\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)

# %%
df.columns
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_offensive', 'ball_recovery_recovery_failure',
#        'block_deflection', 'block_offensive', 'carry_end_location',
#        'clearance_aerial_won', 'counterpress', 'dribble_nutmeg',
#        'dribble_outcome', 'dribble_overrun', 'duel_outcome', 'duel_type',
#        'duration', 'foul_committed_advantage', 'foul_committed_card',
#        'foul_committed_penalty', 'foul_won_advantage', 'foul_won_defensive',
#        'foul_won_penalty', 'goalkeeper_body_part', 'goalkeeper_end_location',
#        'goalkeeper_outcome', 'goalkeeper_position', 'goalkeeper_technique',
#        'goalkeeper_type', 'id', 'index', 'interception_outcome', 'location',
#        'match_id', 'minute', 'pass_aerial_won', 'pass_angle',
#        'pass_assisted_shot_id', 'pass_backheel', 'pass_body_part',
#        'pass_cross', 'pass_deflected', 'pass_end_location', 'pass_goal_assist',
#        'pass_height', 'pass_length', 'pass_miscommunication', 'pass_outcome',
#        'pass_recipient', 'pass_shot_assist', 'pass_switch', 'pass_type',
#        'period', 'play_pattern', 'player', 'player_id', 'position',
#        'possession', 'possession_team', 'possession_team_id', 'related_events',
#        'second', 'shot_body_part', 'shot_end_location', 'shot_first_time',
#        'shot_freeze_frame', 'shot_key_pass_id', 'shot_one_on_one',
#        'shot_outcome', 'shot_redirect', 'shot_statsbomb_xg', 'shot_technique',
#        'shot_type', 'substitution_outcome', 'substitution_replacement',
#        'tactics', 'team', 'timestamp', 'type', 'under_pressure'],
#       dtype='object')

# %%
df=df[df['team']=='France']

# %%
df=df[['type','minute','location','pass_end_location','player_id','player','pass_recipient','id','pass_outcome']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1565 entries, 0 to 3546
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               1565 non-null   object
#  1   minute             1565 non-null   int64
#  2   location           1534 non-null   object
#  3   pass_end_location  350 non-null    object
#  4   player_id          1541 non-null   float64
#  5   player             1541 non-null   object
#  6   pass_recipient     335 non-null    object
#  7   id                 1565 non-null   object
#  8   pass_outcome       67 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 122.3+ KB

# %%
subs=df[df['type']=='Substitution']

# %%
subs=subs['minute']

# %%
firstsub=subs.min()
firstsub
# Out:
# 74

# %%
df=df[df['type']=='Pass']

# %%
df['pass_outcome'].fillna('Complete',inplace=True)

# %%
df=df[df['type']=='Pass']

# %%
df=df[df['pass_outcome']=='Complete']

# %%
df
# Out:
#      type  minute      location pass_end_location  player_id  \
# 6    Pass       0  [60.0, 42.0]      [33.0, 55.0]     5487.0
# 9    Pass       0  [37.0, 55.0]      [45.0, 75.0]    20004.0
# 10   Pass       0  [47.0, 75.0]      [28.0, 73.0]     3009.0
# 11   Pass       0  [26.0, 67.0]       [8.0, 44.0]     5476.0
# 12   Pass       0   [8.0, 42.0]      [12.0, 21.0]     3099.0
# ..    ...     ...           ...               ...        ...
# 850  Pass      88  [14.0, 71.0]      [23.0, 78.0]     2948.0
# 851  Pass      88  [21.0, 78.0]       [7.0, 76.0]     3254.0
# 868  Pass      91  [15.0, 15.0]      [72.0, 25.0]     3099.0
# 883  Pass      92  [47.0, 41.0]      [56.0, 45.0]     5480.0
# 885  Pass      94  [67.0, 27.0]     [109.0, 21.0]     5492.0
#
#                    player        pass_recipient  \
# 6       Antoine Griezmann        Raphaël Varane
# 9              Paul Pogba  Kylian Mbappé Lottin
# 10   Kylian Mbappé Lottin       Benjamin Pavard
# 11        Benjamin Pavard           Hugo Lloris
# 12            Hugo Lloris    Samuel Yves Umtiti
# ..                    ...                   ...
# 850           Nabil Fekir       Florian Thauvin
# 851       Florian Thauvin       Benjamin Pavard
# 868           Hugo Lloris           Nabil Fekir
# 883      Corentin Tolisso            Paul Pogba
# 885    Samuel Yves Umtiti        Olivier Giroud
#
#                                        id pass_outcome
# 6    297180ed-6ff2-4e49-8ff8-510ff6882abe     Complete
# 9    abda3dfe-e021-4eb9-98e6-4dfdb915f528     Complete
# 10   c70beba2-e7c2-4fa3-99d2-de691150bac2     Complete
# 11   79f60b43-5801-457a-81d1-216c5896df39     Complete
# 12   a66c39f9-0bc3-4423-a414-823fcabdf760     Complete
# ..                                    ...          ...
# 850  d836db01-3fb1-4ec6-b3bd-5e4a25bb76d2     Complete
# 851  4200b3db-5dd7-47c2-9732-431cb9b106a6     Complete
# 868  90b3b6fd-1b09-4b1d-ab51-e48be5f59550     Complete
# 883  b087b915-6e62-43b8-a331-d3adb9ec8417     Complete
# 885  1afbb543-ef50-4c03-b5c1-30206a2c96a0     Complete
#
# [283 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 283 entries, 6 to 885
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               283 non-null    object
#  1   minute             283 non-null    int64
#  2   location           283 non-null    object
#  3   pass_end_location  283 non-null    object
#  4   player_id          283 non-null    float64
#  5   player             283 non-null    object
#  6   pass_recipient     283 non-null    object
#  7   id                 283 non-null    object
#  8   pass_outcome       283 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 22.1+ KB

# %%
successful=df[df['minute']<firstsub]

# %%
successful
# Out:
#      type  minute      location pass_end_location  player_id  \
# 6    Pass       0  [60.0, 42.0]      [33.0, 55.0]     5487.0
# 9    Pass       0  [37.0, 55.0]      [45.0, 75.0]    20004.0
# 10   Pass       0  [47.0, 75.0]      [28.0, 73.0]     3009.0
# 11   Pass       0  [26.0, 67.0]       [8.0, 44.0]     5476.0
# 12   Pass       0   [8.0, 42.0]      [12.0, 21.0]     3099.0
# ..    ...     ...           ...               ...        ...
# 699  Pass      73  [39.0, 21.0]      [28.0, 54.0]     3961.0
# 700  Pass      73  [31.0, 54.0]      [34.0, 42.0]     5485.0
# 701  Pass      73  [34.0, 40.0]      [27.0, 26.0]     3961.0
# 702  Pass      73  [28.0, 25.0]      [53.0, 30.0]     5492.0
# 703  Pass      73  [54.0, 30.0]      [47.0, 41.0]     4375.0
#
#                    player        pass_recipient  \
# 6       Antoine Griezmann        Raphaël Varane
# 9              Paul Pogba  Kylian Mbappé Lottin
# 10   Kylian Mbappé Lottin       Benjamin Pavard
# 11        Benjamin Pavard           Hugo Lloris
# 12            Hugo Lloris    Samuel Yves Umtiti
# ..                    ...                   ...
# 699         N''Golo Kanté        Raphaël Varane
# 700        Raphaël Varane         N''Golo Kanté
# 701         N''Golo Kanté    Samuel Yves Umtiti
# 702    Samuel Yves Umtiti        Blaise Matuidi
# 703        Blaise Matuidi            Paul Pogba
#
#                                        id pass_outcome
# 6    297180ed-6ff2-4e49-8ff8-510ff6882abe     Complete
# 9    abda3dfe-e021-4eb9-98e6-4dfdb915f528     Complete
# 10   c70beba2-e7c2-4fa3-99d2-de691150bac2     Complete
# 11   79f60b43-5801-457a-81d1-216c5896df39     Complete
# 12   a66c39f9-0bc3-4423-a414-823fcabdf760     Complete
# ..                                    ...          ...
# 699  d31c0141-f5dc-42e9-8ec2-9a0735d84a91     Complete
# 700  30ae0b7d-cf0d-4cd2-a0fe-9770407a4b36     Complete
# 701  f2028311-567a-4bd8-a8d7-f67d0e9a9220     Complete
# 702  328d584d-1d93-4192-9295-7e6c59e22cfc     Complete
# 703  645e42f7-3921-457e-96e1-80fd8896f112     Complete
#
# [242 rows x 9 columns]

# %%
l=[]
for i in successful['location']:
    l.append(i[0])
successful['x']=l
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_97640\3797465833.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successful['x']=l

# %%
l1=[]
for i in successful['location']:
    l1.append(i[1])
successful['y']=l1
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_97640\3132810158.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successful['y']=l1

# %%
l3=[]
for i in successful['pass_end_location']:
    l3.append(i[0])
successful['x_final']=l3
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_97640\260152025.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successful['x_final']=l3

# %%
l4=[]
for i in successful['pass_end_location']:
    l4.append(i[1])
successful['y_final']=l4
# Out:
# C:\Users\aakas\AppData\Local\Temp\ipykernel_97640\4098569611.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successful['y_final']=l4

# %%
successful
# Out:
#      type  minute      location pass_end_location  player_id  \
# 6    Pass       0  [60.0, 42.0]      [33.0, 55.0]     5487.0
# 9    Pass       0  [37.0, 55.0]      [45.0, 75.0]    20004.0
# 10   Pass       0  [47.0, 75.0]      [28.0, 73.0]     3009.0
# 11   Pass       0  [26.0, 67.0]       [8.0, 44.0]     5476.0
# 12   Pass       0   [8.0, 42.0]      [12.0, 21.0]     3099.0
# ..    ...     ...           ...               ...        ...
# 699  Pass      73  [39.0, 21.0]      [28.0, 54.0]     3961.0
# 700  Pass      73  [31.0, 54.0]      [34.0, 42.0]     5485.0
# 701  Pass      73  [34.0, 40.0]      [27.0, 26.0]     3961.0
# 702  Pass      73  [28.0, 25.0]      [53.0, 30.0]     5492.0
# 703  Pass      73  [54.0, 30.0]      [47.0, 41.0]     4375.0
#
#                    player        pass_recipient  \
# 6       Antoine Griezmann        Raphaël Varane
# 9              Paul Pogba  Kylian Mbappé Lottin
# 10   Kylian Mbappé Lottin       Benjamin Pavard
# 11        Benjamin Pavard           Hugo Lloris
# 12            Hugo Lloris    Samuel Yves Umtiti
# ..                    ...                   ...
# 699         N''Golo Kanté        Raphaël Varane
# 700        Raphaël Varane         N''Golo Kanté
# 701         N''Golo Kanté    Samuel Yves Umtiti
# 702    Samuel Yves Umtiti        Blaise Matuidi
# 703        Blaise Matuidi            Paul Pogba
#
#                                        id pass_outcome     x     y  x_final  \
# 6    297180ed-6ff2-4e49-8ff8-510ff6882abe     Complete  60.0  42.0     33.0
# 9    abda3dfe-e021-4eb9-98e6-4dfdb915f528     Complete  37.0  55.0     45.0
# 10   c70beba2-e7c2-4fa3-99d2-de691150bac2     Complete  47.0  75.0     28.0
# 11   79f60b43-5801-457a-81d1-216c5896df39     Complete  26.0  67.0      8.0
# 12   a66c39f9-0bc3-4423-a414-823fcabdf760     Complete   8.0  42.0     12.0
# ..                                    ...          ...   ...   ...      ...
# 699  d31c0141-f5dc-42e9-8ec2-9a0735d84a91     Complete  39.0  21.0     28.0
# 700  30ae0b7d-cf0d-4cd2-a0fe-9770407a4b36     Complete  31.0  54.0     34.0
# 701  f2028311-567a-4bd8-a8d7-f67d0e9a9220     Complete  34.0  40.0     27.0
# 702  328d584d-1d93-4192-9295-7e6c59e22cfc     Complete  28.0  25.0     53.0
# 703  645e42f7-3921-457e-96e1-80fd8896f112     Complete  54.0  30.0     47.0
#
#      y_final
# 6       55.0
# 9       75.0
# 10      73.0
# 11      44.0
# 12      21.0
# ..       ...
# 699     54.0
# 700     42.0
# 701     26.0
# 702     30.0
# 703     41.0
#
# [242 rows x 13 columns]

# %%
average_locations = successful.groupby('player').agg({'x':['mean'],'y':['mean','count']})

# %%
average_locations.columns=['x','y','count']

# %%
average_locations.head(11)
# Out:
#                               x          y  count
# player
# Antoine Griezmann     64.000000  41.090909     11
# Benjamin Pavard       66.681818  71.727273     22
# Blaise Matuidi        59.083333  25.916667     24
# Hugo Lloris           11.846154  38.153846     13
# Kylian Mbappé Lottin  66.800000  62.133333     15
# Lucas Hernández Pi    66.090909   9.090909     11
# N''Golo Kanté         49.717949  36.179487     39
# Olivier Giroud        73.375000  36.750000      8
# Paul Pogba            61.000000  50.103448     29
# Raphaël Varane        46.333333  58.303030     33
# Samuel Yves Umtiti    41.702703  22.054054     37

# %%
successful.groupby(['player','pass_recipient']).head()
# Out:
#      type  minute      location pass_end_location  player_id  \
# 6    Pass       0  [60.0, 42.0]      [33.0, 55.0]     5487.0
# 9    Pass       0  [37.0, 55.0]      [45.0, 75.0]    20004.0
# 10   Pass       0  [47.0, 75.0]      [28.0, 73.0]     3009.0
# 11   Pass       0  [26.0, 67.0]       [8.0, 44.0]     5476.0
# 12   Pass       0   [8.0, 42.0]      [12.0, 21.0]     3099.0
# ..    ...     ...           ...               ...        ...
# 692  Pass      73  [62.0, 28.0]      [70.0, 21.0]     4375.0
# 693  Pass      73  [70.0, 22.0]      [64.0, 26.0]     5487.0
# 694  Pass      73  [62.0, 26.0]      [71.0, 31.0]     4375.0
# 700  Pass      73  [31.0, 54.0]      [34.0, 42.0]     5485.0
# 703  Pass      73  [54.0, 30.0]      [47.0, 41.0]     4375.0
#
#                    player        pass_recipient  \
# 6       Antoine Griezmann        Raphaël Varane
# 9              Paul Pogba  Kylian Mbappé Lottin
# 10   Kylian Mbappé Lottin       Benjamin Pavard
# 11        Benjamin Pavard           Hugo Lloris
# 12            Hugo Lloris    Samuel Yves Umtiti
# ..                    ...                   ...
# 692        Blaise Matuidi     Antoine Griezmann
# 693     Antoine Griezmann        Blaise Matuidi
# 694        Blaise Matuidi  Kylian Mbappé Lottin
# 700        Raphaël Varane         N''Golo Kanté
# 703        Blaise Matuidi            Paul Pogba
#
#                                        id pass_outcome     x     y  x_final  \
# 6    297180ed-6ff2-4e49-8ff8-510ff6882abe     Complete  60.0  42.0     33.0
# 9    abda3dfe-e021-4eb9-98e6-4dfdb915f528     Complete  37.0  55.0     45.0
# 10   c70beba2-e7c2-4fa3-99d2-de691150bac2     Complete  47.0  75.0     28.0
# 11   79f60b43-5801-457a-81d1-216c5896df39     Complete  26.0  67.0      8.0
# 12   a66c39f9-0bc3-4423-a414-823fcabdf760     Complete   8.0  42.0     12.0
# ..                                    ...          ...   ...   ...      ...
# 692  01bffbf8-5731-4791-aa38-ae3ff2155293     Complete  62.0  28.0     70.0
# 693  294da7e4-b916-4f3a-943c-cd109e5450da     Complete  70.0  22.0     64.0
# 694  4af7cbb9-1b70-4b29-bf57-b45433e16ac3     Complete  62.0  26.0     71.0
# 700  30ae0b7d-cf0d-4cd2-a0fe-9770407a4b36     Complete  31.0  54.0     34.0
# 703  645e42f7-3921-457e-96e1-80fd8896f112     Complete  54.0  30.0     47.0
#
#      y_final
# 6       55.0
# 9       75.0
# 10      73.0
# 11      44.0
# 12      21.0
# ..       ...
# 692     21.0
# 693     26.0
# 694     31.0
# 700     42.0
# 703     41.0
#
# [217 rows x 13 columns]

# %%
pass_between=successful.groupby(['player','pass_recipient']).id.count().reset_index()
pass_between.rename({'id':'pass_count'},axis='columns',inplace=True)

# %%
pass_between.head(50)
# Out:
#                   player        pass_recipient  pass_count
# 0      Antoine Griezmann       Benjamin Pavard           1
# 1      Antoine Griezmann        Blaise Matuidi           2
# 2      Antoine Griezmann  Kylian Mbappé Lottin           1
# 3      Antoine Griezmann    Lucas Hernández Pi           2
# 4      Antoine Griezmann            Paul Pogba           4
# 5      Antoine Griezmann        Raphaël Varane           1
# 6        Benjamin Pavard     Antoine Griezmann           1
# 7        Benjamin Pavard           Hugo Lloris           2
# 8        Benjamin Pavard  Kylian Mbappé Lottin           5
# 9        Benjamin Pavard         N''Golo Kanté           1
# 10       Benjamin Pavard        Olivier Giroud           1
# 11       Benjamin Pavard            Paul Pogba           5
# 12       Benjamin Pavard        Raphaël Varane           7
# 13        Blaise Matuidi     Antoine Griezmann           2
# 14        Blaise Matuidi  Kylian Mbappé Lottin           4
# 15        Blaise Matuidi    Lucas Hernández Pi           2
# 16        Blaise Matuidi         N''Golo Kanté           8
# 17        Blaise Matuidi        Olivier Giroud           1
# 18        Blaise Matuidi            Paul Pogba           5
# 19        Blaise Matuidi    Samuel Yves Umtiti           2
# 20           Hugo Lloris       Benjamin Pavard           1
# 21           Hugo Lloris         N''Golo Kanté           4
# 22           Hugo Lloris        Olivier Giroud           3
# 23           Hugo Lloris        Raphaël Varane           3
# 24           Hugo Lloris    Samuel Yves Umtiti           2
# 25  Kylian Mbappé Lottin     Antoine Griezmann           2
# 26  Kylian Mbappé Lottin       Benjamin Pavard           3
# 27  Kylian Mbappé Lottin        Blaise Matuidi           3
# 28  Kylian Mbappé Lottin         N''Golo Kanté           1
# 29  Kylian Mbappé Lottin        Olivier Giroud           1
# 30  Kylian Mbappé Lottin            Paul Pogba           5
# 31    Lucas Hernández Pi     Antoine Griezmann           1
# 32    Lucas Hernández Pi       Benjamin Pavard           1
# 33    Lucas Hernández Pi        Blaise Matuidi           2
# 34    Lucas Hernández Pi         N''Golo Kanté           1
# 35    Lucas Hernández Pi        Olivier Giroud           1
# 36    Lucas Hernández Pi    Samuel Yves Umtiti           5
# 37         N''Golo Kanté     Antoine Griezmann           2
# 38         N''Golo Kanté       Benjamin Pavard           2
# 39         N''Golo Kanté        Blaise Matuidi           4
# 40         N''Golo Kanté           Hugo Lloris           1
# 41         N''Golo Kanté  Kylian Mbappé Lottin           3
# 42         N''Golo Kanté    Lucas Hernández Pi           3
# 43         N''Golo Kanté        Olivier Giroud           1
# 44         N''Golo Kanté            Paul Pogba           7
# 45         N''Golo Kanté        Raphaël Varane           8
# 46         N''Golo Kanté    Samuel Yves Umtiti           8
# 47        Olivier Giroud     Antoine Griezmann           3
# 48        Olivier Giroud        Blaise Matuidi           1
# 49        Olivier Giroud  Kylian Mbappé Lottin           3

# %%
pass_between=pass_between.merge(average_locations, left_on ='player',right_index=True)
pass_between=pass_between.merge(average_locations, left_on ='pass_recipient',right_index=True)

# %%
pass_between.head(50)
# Out:
#                   player        pass_recipient  pass_count        x_x  \
# 0      Antoine Griezmann       Benjamin Pavard           1  64.000000
# 20           Hugo Lloris       Benjamin Pavard           1  11.846154
# 26  Kylian Mbappé Lottin       Benjamin Pavard           3  66.800000
# 32    Lucas Hernández Pi       Benjamin Pavard           1  66.090909
# 38         N''Golo Kanté       Benjamin Pavard           2  49.717949
# 52            Paul Pogba       Benjamin Pavard           5  61.000000
# 60        Raphaël Varane       Benjamin Pavard           5  46.333333
# 1      Antoine Griezmann        Blaise Matuidi           2  64.000000
# 27  Kylian Mbappé Lottin        Blaise Matuidi           3  66.800000
# 33    Lucas Hernández Pi        Blaise Matuidi           2  66.090909
# 39         N''Golo Kanté        Blaise Matuidi           4  49.717949
# 48        Olivier Giroud        Blaise Matuidi           1  73.375000
# 53            Paul Pogba        Blaise Matuidi           2  61.000000
# 61        Raphaël Varane        Blaise Matuidi           1  46.333333
# 69    Samuel Yves Umtiti        Blaise Matuidi           7  41.702703
# 2      Antoine Griezmann  Kylian Mbappé Lottin           1  64.000000
# 8        Benjamin Pavard  Kylian Mbappé Lottin           5  66.681818
# 14        Blaise Matuidi  Kylian Mbappé Lottin           4  59.083333
# 41         N''Golo Kanté  Kylian Mbappé Lottin           3  49.717949
# 49        Olivier Giroud  Kylian Mbappé Lottin           3  73.375000
# 54            Paul Pogba  Kylian Mbappé Lottin           5  61.000000
# 63        Raphaël Varane  Kylian Mbappé Lottin           8  46.333333
# 3      Antoine Griezmann    Lucas Hernández Pi           2  64.000000
# 15        Blaise Matuidi    Lucas Hernández Pi           2  59.083333
# 42         N''Golo Kanté    Lucas Hernández Pi           3  49.717949
# 50        Olivier Giroud    Lucas Hernández Pi           1  73.375000
# 55            Paul Pogba    Lucas Hernández Pi           1  61.000000
# 71    Samuel Yves Umtiti    Lucas Hernández Pi           3  41.702703
# 4      Antoine Griezmann            Paul Pogba           4  64.000000
# 11       Benjamin Pavard            Paul Pogba           5  66.681818
# 18        Blaise Matuidi            Paul Pogba           5  59.083333
# 30  Kylian Mbappé Lottin            Paul Pogba           5  66.800000
# 44         N''Golo Kanté            Paul Pogba           7  49.717949
# 66        Raphaël Varane            Paul Pogba           5  46.333333
# 74    Samuel Yves Umtiti            Paul Pogba           3  41.702703
# 5      Antoine Griezmann        Raphaël Varane           1  64.000000
# 12       Benjamin Pavard        Raphaël Varane           7  66.681818
# 23           Hugo Lloris        Raphaël Varane           3  11.846154
# 45         N''Golo Kanté        Raphaël Varane           8  49.717949
# 58            Paul Pogba        Raphaël Varane           3  61.000000
# 75    Samuel Yves Umtiti        Raphaël Varane           6  41.702703
# 6        Benjamin Pavard     Antoine Griezmann           1  66.681818
# 13        Blaise Matuidi     Antoine Griezmann           2  59.083333
# 25  Kylian Mbappé Lottin     Antoine Griezmann           2  66.800000
# 31    Lucas Hernández Pi     Antoine Griezmann           1  66.090909
# 37         N''Golo Kanté     Antoine Griezmann           2  49.717949
# 47        Olivier Giroud     Antoine Griezmann           3  73.375000
# 51            Paul Pogba     Antoine Griezmann           3  61.000000
# 68    Samuel Yves Umtiti     Antoine Griezmann           2  41.702703
# 7        Benjamin Pavard           Hugo Lloris           2  66.681818
#
#           y_x  count_x        x_y        y_y  count_y
# 0   41.090909       11  66.681818  71.727273       22
# 20  38.153846       13  66.681818  71.727273       22
# 26  62.133333       15  66.681818  71.727273       22
# 32   9.090909       11  66.681818  71.727273       22
# 38  36.179487       39  66.681818  71.727273       22
# 52  50.103448       29  66.681818  71.727273       22
# 60  58.303030       33  66.681818  71.727273       22
# 1   41.090909       11  59.083333  25.916667       24
# 27  62.133333       15  59.083333  25.916667       24
# 33   9.090909       11  59.083333  25.916667       24
# 39  36.179487       39  59.083333  25.916667       24
# 48  36.750000        8  59.083333  25.916667       24
# 53  50.103448       29  59.083333  25.916667       24
# 61  58.303030       33  59.083333  25.916667       24
# 69  22.054054       37  59.083333  25.916667       24
# 2   41.090909       11  66.800000  62.133333       15
# 8   71.727273       22  66.800000  62.133333       15
# 14  25.916667       24  66.800000  62.133333       15
# 41  36.179487       39  66.800000  62.133333       15
# 49  36.750000        8  66.800000  62.133333       15
# 54  50.103448       29  66.800000  62.133333       15
# 63  58.303030       33  66.800000  62.133333       15
# 3   41.090909       11  66.090909   9.090909       11
# 15  25.916667       24  66.090909   9.090909       11
# 42  36.179487       39  66.090909   9.090909       11
# 50  36.750000        8  66.090909   9.090909       11
# 55  50.103448       29  66.090909   9.090909       11
# 71  22.054054       37  66.090909   9.090909       11
# 4   41.090909       11  61.000000  50.103448       29
# 11  71.727273       22  61.000000  50.103448       29
# 18  25.916667       24  61.000000  50.103448       29
# 30  62.133333       15  61.000000  50.103448       29
# 44  36.179487       39  61.000000  50.103448       29
# 66  58.303030       33  61.000000  50.103448       29
# 74  22.054054       37  61.000000  50.103448       29
# 5   41.090909       11  46.333333  58.303030       33
# 12  71.727273       22  46.333333  58.303030       33
# 23  38.153846       13  46.333333  58.303030       33
# 45  36.179487       39  46.333333  58.303030       33
# 58  50.103448       29  46.333333  58.303030       33
# 75  22.054054       37  46.333333  58.303030       33
# 6   71.727273       22  64.000000  41.090909       11
# 13  25.916667       24  64.000000  41.090909       11
# 25  62.133333       15  64.000000  41.090909       11
# 31   9.090909       11  64.000000  41.090909       11
# 37  36.179487       39  64.000000  41.090909       11
# 47  36.750000        8  64.000000  41.090909       11
# 51  50.103448       29  64.000000  41.090909       11
# 68  22.054054       37  64.000000  41.090909       11
# 7   71.727273       22  11.846154  38.153846       13

# %%
pass_between=pass_between[pass_between['pass_count']>1]

# %%
from mplsoccer.pitch import Pitch

# %%
k=sb.lineups(match_id=7580)['France']

# %%
k['player']=k['player_name']

# %%
k
# Out:
#     player_id           player_name  player_nickname  jersey_number country  \
# 0        2948           Nabil Fekir             None             18  France
# 1        3009  Kylian Mbappé Lottin    Kylian Mbappé             10  France
# 2        3099           Hugo Lloris             None              1  France
# 3        3254       Florian Thauvin             None             20  France
# 4        3604        Olivier Giroud             None              9  France
# 5        3961         N''Golo Kanté     N'Golo Kanté             13  France
# 6        4375        Blaise Matuidi             None             14  France
# 7        5476       Benjamin Pavard             None              2  France
# 8        5480      Corentin Tolisso             None             12  France
# 9        5484    Lucas Hernández Pi  Lucas Hernandez             21  France
# 10       5485        Raphaël Varane             None              4  France
# 11       5487     Antoine Griezmann             None              7  France
# 12       5492    Samuel Yves Umtiti    Samuel Umtiti              5  France
# 13      20004            Paul Pogba             None              6  France
#
#                                                 cards  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [{'time': '93:18', 'card_type': 'Yellow Card',...
# 5                                                  []
# 6   [{'time': '71:18', 'card_type': 'Yellow Card',...
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
#
#                                             positions                player
# 0   [{'position_id': 7, 'position': 'Right Wing Ba...           Nabil Fekir
# 1   [{'position_id': 17, 'position': 'Right Wing',...  Kylian Mbappé Lottin
# 2   [{'position_id': 1, 'position': 'Goalkeeper', ...           Hugo Lloris
# 3   [{'position_id': 17, 'position': 'Right Wing',...       Florian Thauvin
# 4   [{'position_id': 23, 'position': 'Center Forwa...        Olivier Giroud
# 5   [{'position_id': 11, 'position': 'Left Defensi...         N''Golo Kanté
# 6   [{'position_id': 21, 'position': 'Left Wing', ...        Blaise Matuidi
# 7   [{'position_id': 2, 'position': 'Right Back', ...       Benjamin Pavard
# 8   [{'position_id': 21, 'position': 'Left Wing', ...      Corentin Tolisso
# 9   [{'position_id': 6, 'position': 'Left Back', '...    Lucas Hernández Pi
# 10  [{'position_id': 3, 'position': 'Right Center ...        Raphaël Varane
# 11  [{'position_id': 7, 'position': 'Right Wing Ba...     Antoine Griezmann
# 12  [{'position_id': 5, 'position': 'Left Center B...    Samuel Yves Umtiti
# 13  [{'position_id': 9, 'position': 'Right Defensi...            Paul Pogba

# %%
t=pd.merge(k,average_locations, how='outer', on=['player'])

# %%
t=t.drop('player_nickname',axis=1)

# %%
t.dropna(axis=0,inplace=True)

# %%
maxwidth=10
pass_between['width'] = (pass_between.pass_count / pass_between.pass_count.max() *maxwidth)
pass_between.head(20)
# Out:
#                   player        pass_recipient  pass_count        x_x  \
# 26  Kylian Mbappé Lottin       Benjamin Pavard           3  66.800000
# 52            Paul Pogba       Benjamin Pavard           5  61.000000
# 60        Raphaël Varane       Benjamin Pavard           5  46.333333
# 27  Kylian Mbappé Lottin        Blaise Matuidi           3  66.800000
# 39         N''Golo Kanté        Blaise Matuidi           4  49.717949
# 69    Samuel Yves Umtiti        Blaise Matuidi           7  41.702703
# 8        Benjamin Pavard  Kylian Mbappé Lottin           5  66.681818
# 14        Blaise Matuidi  Kylian Mbappé Lottin           4  59.083333
# 41         N''Golo Kanté  Kylian Mbappé Lottin           3  49.717949
# 49        Olivier Giroud  Kylian Mbappé Lottin           3  73.375000
# 54            Paul Pogba  Kylian Mbappé Lottin           5  61.000000
# 63        Raphaël Varane  Kylian Mbappé Lottin           8  46.333333
# 42         N''Golo Kanté    Lucas Hernández Pi           3  49.717949
# 71    Samuel Yves Umtiti    Lucas Hernández Pi           3  41.702703
# 4      Antoine Griezmann            Paul Pogba           4  64.000000
# 11       Benjamin Pavard            Paul Pogba           5  66.681818
# 18        Blaise Matuidi            Paul Pogba           5  59.083333
# 30  Kylian Mbappé Lottin            Paul Pogba           5  66.800000
# 44         N''Golo Kanté            Paul Pogba           7  49.717949
# 66        Raphaël Varane            Paul Pogba           5  46.333333
#
#           y_x  count_x        x_y        y_y  count_y     width
# 26  62.133333       15  66.681818  71.727273       22  3.333333
# 52  50.103448       29  66.681818  71.727273       22  5.555556
# 60  58.303030       33  66.681818  71.727273       22  5.555556
# 27  62.133333       15  59.083333  25.916667       24  3.333333
# 39  36.179487       39  59.083333  25.916667       24  4.444444
# 69  22.054054       37  59.083333  25.916667       24  7.777778
# 8   71.727273       22  66.800000  62.133333       15  5.555556
# 14  25.916667       24  66.800000  62.133333       15  4.444444
# 41  36.179487       39  66.800000  62.133333       15  3.333333
# 49  36.750000        8  66.800000  62.133333       15  3.333333
# 54  50.103448       29  66.800000  62.133333       15  5.555556
# 63  58.303030       33  66.800000  62.133333       15  8.888889
# 42  36.179487       39  66.090909   9.090909       11  3.333333
# 71  22.054054       37  66.090909   9.090909       11  3.333333
# 4   41.090909       11  61.000000  50.103448       29  4.444444
# 11  71.727273       22  61.000000  50.103448       29  5.555556
# 18  25.916667       24  61.000000  50.103448       29  5.555556
# 30  62.133333       15  61.000000  50.103448       29  5.555556
# 44  36.179487       39  61.000000  50.103448       29  7.777778
# 66  58.303030       33  61.000000  50.103448       29  5.555556

# %%
d=t['count'].max()
maxsize=10
t['marksize']=(t['count']/d * maxsize)

# %%
t
# Out:
#     player_id           player_name  jersey_number country  \
# 1        3009  Kylian Mbappé Lottin             10  France
# 2        3099           Hugo Lloris              1  France
# 4        3604        Olivier Giroud              9  France
# 5        3961         N''Golo Kanté             13  France
# 6        4375        Blaise Matuidi             14  France
# 7        5476       Benjamin Pavard              2  France
# 9        5484    Lucas Hernández Pi             21  France
# 10       5485        Raphaël Varane              4  France
# 11       5487     Antoine Griezmann              7  France
# 12       5492    Samuel Yves Umtiti              5  France
# 13      20004            Paul Pogba              6  France
#
#                                                 cards  \
# 1                                                  []
# 2                                                  []
# 4   [{'time': '93:18', 'card_type': 'Yellow Card',...
# 5                                                  []
# 6   [{'time': '71:18', 'card_type': 'Yellow Card',...
# 7                                                  []
# 9                                                  []
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
#
#                                             positions                player  \
# 1   [{'position_id': 17, 'position': 'Right Wing',...  Kylian Mbappé Lottin
# 2   [{'position_id': 1, 'position': 'Goalkeeper', ...           Hugo Lloris
# 4   [{'position_id': 23, 'position': 'Center Forwa...        Olivier Giroud
# 5   [{'position_id': 11, 'position': 'Left Defensi...         N''Golo Kanté
# 6   [{'position_id': 21, 'position': 'Left Wing', ...        Blaise Matuidi
# 7   [{'position_id': 2, 'position': 'Right Back', ...       Benjamin Pavard
# 9   [{'position_id': 6, 'position': 'Left Back', '...    Lucas Hernández Pi
# 10  [{'position_id': 3, 'position': 'Right Center ...        Raphaël Varane
# 11  [{'position_id': 7, 'position': 'Right Wing Ba...     Antoine Griezmann
# 12  [{'position_id': 5, 'position': 'Left Center B...    Samuel Yves Umtiti
# 13  [{'position_id': 9, 'position': 'Right Defensi...            Paul Pogba
#
#             x          y  count   marksize
# 1   66.800000  62.133333   15.0   3.846154
# 2   11.846154  38.153846   13.0   3.333333
# 4   73.375000  36.750000    8.0   2.051282
# 5   49.717949  36.179487   39.0  10.000000
# 6   59.083333  25.916667   24.0   6.153846
# 7   66.681818  71.727273   22.0   5.641026
# 9   66.090909   9.090909   11.0   2.820513
# 10  46.333333  58.303030   33.0   8.461538
# 11  64.000000  41.090909   11.0   2.820513
# 12  41.702703  22.054054   37.0   9.487179
# 13  61.000000  50.103448   29.0   7.435897

# %%
pitch=Pitch(pitch_color='black',line_color='white')
fig,ax = pitch.draw()
arrows=pitch.lines(pass_between.x_x,pass_between.y_x,pass_between.x_y,pass_between.y_y,ax=ax,linewidth=pass_between['width']*2,color='white',zorder=1,alpha=0.7)
nodes =pitch.scatter(t.x,t.y,s=65*t.marksize,color='#3049e3',edgecolor='white',linewidth=1.5,alpha=1,zorder=1,ax=ax)
for index, row in t.iterrows():
    pitch.annotate(row.jersey_number, xy=(row.x, row.y), c='white', va='center',
                   ha='center', size=10, weight='bold', ax=ax)
